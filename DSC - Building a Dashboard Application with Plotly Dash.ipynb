# %% [markdown]
# # Applied Data Science Capstone: SpaceX Falcon 9 First Stage Landing Prediction

# %% [markdown]
# ## Part 7: Building a Dashboard Application with Plotly Dash

# %%
# !pip install dash
# !pip install dash==1.19.0
# !pip install jupyter_dash
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: dash in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (1.19.0)
# Requirement already satisfied: Flask>=1.0.4 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash) (4.11.2)
# Requirement already satisfied: dash-renderer==1.9.0 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash) (1.9.0)
# Requirement already satisfied: plotly in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash) (5.5.0)
# Requirement already satisfied: flask-compress in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash) (1.10.1)
# Requirement already satisfied: dash-html-components==1.1.2 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash) (1.1.2)
# Requirement already satisfied: dash-core-components==1.15.0 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash) (1.15.0)
# Requirement already satisfied: future in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash) (0.18.2)
# Requirement already satisfied: itsdangerous>=0.24 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash) (1.1.0)
# Requirement already satisfied: click>=5.1 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (1.1.1)
# Requirement already satisfied: brotli in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from plotly->dash) (8.0.1)
# Requirement already satisfied: six in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from plotly->dash) (1.15.0)
# Requirement already satisfied: dash==1.19.0 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (1.19.0)
# Requirement already satisfied: dash-table==4.11.2 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash==1.19.0) (4.11.2)
# Requirement already satisfied: flask-compress in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash==1.19.0) (1.10.1)
# Requirement already satisfied: plotly in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash==1.19.0) (5.5.0)
# Requirement already satisfied: dash-html-components==1.1.2 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: dash-core-components==1.15.0 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash==1.19.0) (1.15.0)
# Requirement already satisfied: future in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash==1.19.0) (0.18.2)
# Requirement already satisfied: dash-renderer==1.9.0 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash==1.19.0) (1.9.0)
# Requirement already satisfied: Flask>=1.0.4 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: click>=5.1 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash==1.19.0) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash==1.19.0) (1.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash==1.19.0) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash==1.19.0) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash==1.19.0) (1.1.1)
# Requirement already satisfied: brotli in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from flask-compress->dash==1.19.0) (1.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from plotly->dash==1.19.0) (8.0.1)
# Requirement already satisfied: six in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from plotly->dash==1.19.0) (1.15.0)
# Requirement already satisfied: jupyter_dash in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: ipykernel in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from jupyter_dash) (5.3.4)
# Requirement already satisfied: ipython in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from jupyter_dash) (7.22.0)
# Requirement already satisfied: flask in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: ansi2html in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from jupyter_dash) (1.6.0)
# Requirement already satisfied: dash in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: retrying in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: requests in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from jupyter_dash) (2.26.0)
# Requirement already satisfied: flask-compress in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash->jupyter_dash) (1.10.1)
# Requirement already satisfied: dash-renderer==1.9.0 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: dash-table==4.11.2 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: plotly in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash->jupyter_dash) (5.5.0)
# Requirement already satisfied: dash-html-components==1.1.2 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-core-components==1.15.0 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: future in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: Werkzeug>=0.15 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from flask->jupyter_dash) (1.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: click>=5.1 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from flask->jupyter_dash) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from flask->jupyter_dash) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (1.1.1)
# Requirement already satisfied: brotli in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: traitlets>=4.1.0 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter_dash) (5.0.5)
# Requirement already satisfied: jupyter-client in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: backcall in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from ipython->jupyter_dash) (3.0.17)
# Requirement already satisfied: jedi>=0.16 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from ipython->jupyter_dash) (0.17.2)
# Requirement already satisfied: decorator in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from ipython->jupyter_dash) (5.0.6)
# Requirement already satisfied: pexpect>4.3 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from ipython->jupyter_dash) (4.8.0)
# Requirement already satisfied: pygments in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from ipython->jupyter_dash) (2.8.1)
# Requirement already satisfied: pickleshare in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from ipython->jupyter_dash) (52.0.0.post20210125)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: wcwidth in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from traitlets>=4.1.0->ipykernel->jupyter_dash) (0.2.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from jupyter-client->ipykernel->jupyter_dash) (4.7.1)
# Requirement already satisfied: pyzmq>=13 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from jupyter-client->ipykernel->jupyter_dash) (20.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from jupyter-client->ipykernel->jupyter_dash) (2.8.1)
# Requirement already satisfied: six>=1.5 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.1->jupyter-client->ipykernel->jupyter_dash) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from plotly->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from requests->jupyter_dash) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from requests->jupyter_dash) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from requests->jupyter_dash) (1.26.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from requests->jupyter_dash) (2.0.9)
# Requirement already satisfied: plotly in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (5.5.0)
# Requirement already satisfied: six in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/mrmearrr/anaconda3/lib/python3.8/site-packages (from plotly) (8.0.1)

# %%
spacex_df= pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d088b68ce0b4> in <module>
# ----> 1 spacex_df= pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
#
# NameError: name 'pd' is not defined

# %%
# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
import plotly.express as px

# Read the airline data into pandas dataframe
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()
​
# Create a dash application
app = dash.Dash(__name__)
​
# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                dcc.Dropdown(id='site-dropdown',
                                            options=[
                                                {'label': 'All Sites', 'value': 'ALL'},
                                                {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                                {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
                                            ],
                                            value='ALL',
                                            placeholder="Select a Launch Site here",
                                            searchable=True
                                            ),
                                html.Br(),
​
                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),
​
                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)
                                dcc.RangeSlider(id='payload-slider',
                                                min=0, max=10000, step=1000,
                                                marks={0: '0', 2500: '2500', 5000: '5000', 7500: '7500', 10000: '10000'},
                                                value=[min_payload, max_payload]),
                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])
​
# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
# Function decorator to specify function input and output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
        names='Launch Site', 
        title='Total Success Launches By Site')
        return fig
    else:
        # return the outcomes piechart for a selected site
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby(['Launch Site', 'class']).size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count', 
        names='class',
        title='Total Success Launched for site {entered_site}')
        return fig
# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart', component_property='figure'),
              [Input(component_id='site-dropdown', component_property='value'), 
              Input(component_id='payload-slider', component_property='value')])
def get_scatter_chart(entered_site, payload):
    low, high = payload
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)'] > low) & (spacex_df['Payload Mass (kg)'] < high)]       
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class', 
        color='Booster Version Category',
        title='Correlation between Payload and Success for all Sites')
        return fig
    else:
        fig = px.scatter(filtered_df[filtered_df['Launch Site'] == entered_site],
        x='Payload Mass (kg)', y='class',
        color='Booster Version Category',
        title=f'Correlation between Payload and Success for site {entered_site}')
        return fig
​
# Run the app
if __name__ == '__main__':
    app.run_server()
